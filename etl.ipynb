# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: postgres in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (4.0)
# Requirement already satisfied: psycopg2-binary>=2.8 in /opt/conda/lib/python3.10/site-packages (from postgres->-r requirements.txt (line 1)) (2.9.5)
# Requirement already satisfied: psycopg2-pool in /opt/conda/lib/python3.10/site-packages (from postgres->-r requirements.txt (line 1)) (1.1)

# %%
# create a db file
from sqlalchemy import create_engine

# %%
import os
import glob
import psycopg2
import pandas as pd
import datetime
from sql_queries import *

# %%
conn = psycopg2.connect("host= pgdatabase dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("./data/song_data")

# %%
song_files
# Out:
# ['/home/jovyan/work/data/song_data/A/A/A/TRAAAAW128F429D538.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAABD128F429CF47.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAADZ128F9348C2E.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAEF128F4273421.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAFD128F92F423A.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAMO128F1481E7F.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAMQ128F1460CD3.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAPK128E0786D96.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAARJ128F9320760.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAVG12903CFA543.json',
#  '/home/jovyan/work/data/song_data/A/A/A/TRAAAVO128F93133D4.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABCL128F4286650.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABDL12903CAABBA.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABJL12903CDCF1A.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABJV128F1460C49.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABLR128F423B7E3.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABNV128F425CEE1.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABRB128F9306DD5.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABVM128F92CA9DC.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABXG128F9318EBD.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABYN12903CFD305.json',
#  '/home/jovyan/work/data/song_data/A/A/B/TRAABYW128F4244559.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACCG128F92E8A55.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACER128F4290F96.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACFV128F935E50B.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACHN128F1489601.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACIW12903CC0F6D.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACLV128F427E123.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACNS128F14A2DF5.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACOW128F933E35F.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACPE128F421C1B9.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACQT128F9331780.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACSL128F93462F4.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACTB12903CAAF15.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACVS128E078BE39.json',
#  '/home/jovyan/work/data/song_data/A/A/C/TRAACZK128F4243829.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABACN128F425B784.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAFJ128F42AF24E.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAFP128F931E9A1.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAIO128F42938F9.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABATO128F42627E9.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAVQ12903CBF7E0.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAWW128F4250A31.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAXL128F424FC50.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAXR128F426515F.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAXV128F92F6AE3.json',
#  '/home/jovyan/work/data/song_data/A/B/A/TRABAZH128F930419A.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBAM128F429D223.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBBV128F42967D7.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBJE12903CDB442.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBKX128F4285205.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBLU128F93349CF.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBNP128F932546F.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBOP128F931B50D.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBOR128F4286200.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBTA128F933D304.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBVJ128F92F7EAA.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBXU128F92FEF48.json',
#  '/home/jovyan/work/data/song_data/A/B/B/TRABBZN12903CD9297.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCAJ12903CDFCC2.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCEC128F426456E.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCEI128F424C983.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCFL128F149BB0D.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCIX128F4265903.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCKL128F423A778.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCPZ128F4275C32.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCRU128F423F449.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCTK128F934B224.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCUQ128E0783E2B.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCXB128F4286BD3.json',
#  '/home/jovyan/work/data/song_data/A/B/C/TRABCYE128F934CE1D.json']

# %%
filepath = song_files[0]

# %%
df = pd.read_json(filepath, lines = True)
df.head()
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD7TVE1187B99BFB1              NaN               NaN
#
#    artist_location artist_name             song_id             title  \
# 0  California - LA      Casual  SOMZWCG12A8C13C480  I Didn't Mean To
#
#     duration  year
# 0  218.93179     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_id = df.iloc[0]["song_id"]
title = df.iloc[0]["title"]
artist_id = df.iloc[0]["artist_id"]
artist_name = df.iloc[0]["artist_name"]
year = int(df.iloc[0]["year"])
duration = df.iloc[0]["duration"]
song_data = tuple((song_id, title, artist_id, artist_name, year, duration))
#song_data = list((df1.song_id, df1.title.values, df1.year, df1.duration))#, df.artist_id.values, df.artist_name.values, df.artist_location.values, df.artist_latitude.values, df.artist_longitude.values))
song_data
# Out:
# ('SOMZWCG12A8C13C480',
#  "I Didn't Mean To",
#  'ARD7TVE1187B99BFB1',
#  'Casual',
#  0,
#  218.93179)

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_id = df.iloc[0]["artist_id"]
artist_name = df.iloc[0]["artist_name"]
artist_location = df.iloc[0]["artist_location"]
artist_latitude = df.iloc[0]["artist_latitude"]
artist_longitude = df.iloc[0]["artist_longitude"]
artist_data = tuple((artist_id, artist_name, artist_location, artist_latitude, artist_longitude))
artist_data
# Out:
# ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan)

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files("data/log_data")

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath, lines = True)
df.head()
# Out:
#     artist       auth firstName gender  itemInSession lastName     length  \
# 0     None  Logged In    Walter      M              0     Frye        NaN
# 1     None  Logged In    Kaylee      F              0  Summers        NaN
# 2  Des'ree  Logged In    Kaylee      F              1  Summers  246.30812
# 3     None  Logged In    Kaylee      F              2  Summers        NaN
# 4  Mr Oizo  Logged In    Kaylee      F              3  Summers  144.03873
#
#   level                           location method      page   registration  \
# 0  free  San Francisco-Oakland-Hayward, CA    GET      Home  1540919166796
# 1  free        Phoenix-Mesa-Scottsdale, AZ    GET      Home  1540344794796
# 2  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1540344794796
# 3  free        Phoenix-Mesa-Scottsdale, AZ    GET   Upgrade  1540344794796
# 4  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1540344794796
#
#    sessionId          song  status             ts  \
# 0         38          None     200  1541105830796
# 1        139          None     200  1541106106796
# 2        139  You Gotta Be     200  1541106106796
# 3        139          None     200  1541106132796
# 4        139       Flat 55     200  1541106352796
#
#                                            userAgent  userId
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      39
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df["page"] == "NextSong"]
df.head()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 2            Des'ree  Logged In    Kaylee      F              1  Summers
# 4            Mr Oizo  Logged In    Kaylee      F              3  Summers
# 5         Tamba Trio  Logged In    Kaylee      F              4  Summers
# 6     The Mars Volta  Logged In    Kaylee      F              5  Summers
# 7  Infected Mushroom  Logged In    Kaylee      F              6  Summers
#
#       length level                     location method      page  \
# 2  246.30812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 4  144.03873  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 5  177.18812  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 6  380.42077  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
# 7  440.26730  free  Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong
#
#     registration  sessionId                          song  status  \
# 2  1540344794796        139                  You Gotta Be     200
# 4  1540344794796        139                       Flat 55     200
# 5  1540344794796        139  Quem Quiser Encontrar O Amor     200
# 6  1540344794796        139                     Eriatarka     200
# 7  1540344794796        139               Becoming Insane     200
#
#               ts                                          userAgent  userId
# 2  1541106106796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 4  1541106352796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 5  1541106496796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6  1541106673796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 7  1541107053796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8

# %%
t = pd.to_datetime(df.ts, unit = "ms")
t.head()
# Out:
# 2   2018-11-01 21:01:46.796
# 4   2018-11-01 21:05:52.796
# 5   2018-11-01 21:08:16.796
# 6   2018-11-01 21:11:13.796
# 7   2018-11-01 21:17:33.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (df.ts, t.dt.hour, t.dt.day, t.dt.isocalendar().week, t.dt.month, t.dt.year, t.dt.weekday)
column_labels = ('timestamp','hour','day','week','month','year','weekday')

# %%
time_df = pd.DataFrame.from_dict(dict(zip(column_labels,time_data)))
time_df.head()
# Out:
#        timestamp  hour  day  week  month  year  weekday
# 2  1541106106796    21    1    44     11  2018        3
# 4  1541106352796    21    1    44     11  2018        3
# 5  1541106496796    21    1    44     11  2018        3
# 6  1541106673796    21    1    44     11  2018        3
# 7  1541107053796    21    1    44     11  2018        3

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[["userId", "firstName", "lastName", "gender", "level"]]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
# insert songplay records
for index, row in df.iterrows():
        
    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()

    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = tuple([row.ts, row.sessionId, row.userId, songid, artistid, row.level, row.location, row.userAgent])
    cur.execute(songplay_table_insert, songplay_data)

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()
